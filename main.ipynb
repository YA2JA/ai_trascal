# %%
# !pip install -r requirements.txt
# !pip install ./bin_trainer-0.0.1-py3-none-any.whl
# Out:
# Package                 Version
# ----------------------- --------------------
# absl-py                 1.4.0
# anyio                   3.5.0
# argon2-cffi             21.3.0
# argon2-cffi-bindings    21.2.0
# asttokens               2.0.5
# attrs                   22.1.0
# backcall                0.2.0
# beautifulsoup4          4.12.2
# bin-trainer             0.0.1
# bleach                  4.1.0
# cachetools              5.3.1
# certifi                 2023.7.22
# cffi                    1.15.1
# charset-normalizer      3.2.0
# colorama                0.4.6
# comm                    0.1.2
# contourpy               1.1.0
# cycler                  0.11.0
# debugpy                 1.5.1
# decorator               5.1.1
# defusedxml              0.7.1
# entrypoints             0.4
# executing               0.8.3
# fastjsonschema          2.16.2
# filelock                3.12.2
# fonttools               4.41.1
# gitdb                   4.0.10
# GitPython               3.1.32
# ...

# %%
# Out:
#   Cell In[3], line 1
#     import bin-trainer
#               ^
# SyntaxError: invalid syntax
